# %% [markdown]
# # Lab 1: Pandas Basics
# This lab will introduce you to basic Python and `pandas`

# %%
import pandas as pd

# %%
import datetime

# %%
# read in data

weather = pd.read_csv('last_ten_alb.csv')

# %%
weather.head()
# Out:
#    Unnamed: 0   timestamp   mean_tmp  mean_tmp_f  dew_point  dew_point_f  \
# 0           0  2012-01-01   5.333333          24       36.0           24
# 1           1  2012-01-02   3.722222          24       27.4           24
# 2           2  2012-01-03  -5.888889          24        9.3           24
# 3           3  2012-01-04 -11.777778          24       -1.1           24
# 4           4  2012-01-05  -3.833333          24       12.8           24
#
#    mean_sea_level_press  mean_sea_level_press_f  mean_stn_pressure  \
# 0                1013.5                      22             1003.5
# 1                1003.9                      23              992.9
# 2                1012.5                      24             1001.0
# 3                1020.8                      24             1009.5
# 4                1012.2                      22             1001.0
#
#    mean_stn_pressure_f  ...  tornado_f    station_id  ctry  state  \
# ...

# %%
weather.describe()
# Out:
#         Unnamed: 0     mean_tmp   mean_tmp_f    dew_point  dew_point_f  \
# count  3888.000000  3888.000000  3888.000000  3888.000000  3888.000000
# mean    178.212449    10.148448    23.995628    38.386548    23.995370
# std     104.738930    10.505663     0.272638    19.387607     0.273105
# min       0.000000   -20.444444     7.000000   -22.400000     7.000000
# 25%      88.000000     1.722222    24.000000    23.400000    24.000000
# 50%     176.000000    10.777778    24.000000    39.000000    24.000000
# 75%     268.000000    19.611111    24.000000    55.200000    24.000000
# max     365.000000    31.111111    24.000000    73.500000    24.000000
#
#        mean_sea_level_press  mean_sea_level_press_f  mean_stn_pressure  \
# count           3886.000000             3888.000000        3873.000000
# mean            1016.921256               22.544753        1006.107255
# std                7.425407                2.424163           7.362618
# ...
